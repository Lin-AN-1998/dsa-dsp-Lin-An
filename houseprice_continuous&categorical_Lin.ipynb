# %% [markdown]
# - The goal of this notebook is to create a first pipeline for the model exploration. This is important if we want to be able to get feedback on the different modeling steps we will be doing (pre-processing, feature engineering, etc) and to know if they are improving the model performance or not.
#
# - This pipeline is composed of:
#     - Dataset loading
#     - The minimum preprocessing or feature engineering required to prepare the data for the model (eg: remove misssing values)
#     - Modeling (a first baseline model)
#     - Evaluation
#     - Preparing submission file to the kaggle competition

# %%
from pathlib import Path
import pandas as pd

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Dataset

# %% [markdown]
# - Read data

# %%
ROOT_DIR = Path('.').resolve().parents[1].absolute()
DATA_DIR = ROOT_DIR / 'data' / 'house-prices'

target_column = 'SalePrice'

# %%
df_master = pd.read_csv("F:\Lectures/2ed\Data science in production\house-prices/train.csv", index_col='Id')
df_master.sample(5)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 414           30       RM         56.0     8960   Pave  Grvl      Reg
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 474           20       RL        110.0    14977   Pave   NaN      IR1
# 187           80       RL          NaN     9947   Pave   NaN      IR1
# 1257          20       RL         91.0    14303   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 414          Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 6            Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 474          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 187          Lvl    AllPub   CulDSac       Gtl      Mitchel       Norm
# 1257         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 414        Norm     1Fam     1Story            5            6       1927
# 6          Norm     1Fam     1.5Fin            5            5       1993
# 474        Norm     1Fam     1Story            8            5       2006
# 187        Norm     1Fam       SLvl            7            5       1990
# 1257       Norm     1Fam     1Story            8            5       1994
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 414           1950     Gable  CompShg     WdShing     Wd Shng       None
# 6             1995     Gable  CompShg     VinylSd     VinylSd       None
# 474           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 187           1991     Gable  CompShg     HdBoard     HdBoard       None
# 1257          1994       Hip  CompShg     HdBoard     HdBoard    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 414          0.0        TA        TA     CBlock       TA       TA
# 6            0.0        TA        TA       Wood       Gd       TA
# 474        304.0        Gd        TA      PConc       Ex       TA
# 187          0.0        TA        TA      PConc       Gd       TA
# 1257       554.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 414            No          Unf           0          Unf           0
# 6              No          GLQ         732          Unf           0
# 474            Gd          GLQ        1350          Unf           0
# 187            Av          GLQ         611          Unf           0
# 1257           Gd          GLQ        1314          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 414        1008         1008    GasA        Gd          Y      FuseA
# 6            64          796    GasA        Ex          Y      SBrkr
# 474         626         1976    GasA        Ex          Y      SBrkr
# 187         577         1188    GasA        Ex          Y      SBrkr
# 1257        672         1986    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 414       1028         0             0       1028             0             0
# 6          796       566             0       1362             1             0
# 474       1976         0             0       1976             1             0
# 187       1217         0             0       1217             1             0
# 1257      1987         0             0       1987             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 414          1         0             2             1          TA
# 6            1         1             1             1          TA
# 474          2         0             2             1          Gd
# 187          2         0             3             1          Gd
# 1257         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 414              5        Typ           1          Gd     Detchd       1927.0
# 6                5        Typ           0         NaN     Attchd       1993.0
# 474              7        Typ           1          Ex     Attchd       2006.0
# 187              6        Typ           0         NaN     Attchd       1990.0
# 1257             7        Typ           1          TA     Attchd       1994.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 414           Unf           2         360         TA         TA          Y
# 6             Unf           2         480         TA         TA          Y
# 474           RFn           3         908         TA         TA          Y
# 187           Unf           2         497         TA         TA          Y
# 1257          Fin           2         691         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 414            0            0            130          0            0
# 6             40           30              0        320            0
# 474          250           63              0          0            0
# 187          168           27              0          0            0
# 1257         262           36              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 414          0    NaN    NaN         NaN        0       3    2010       WD
# 6            0    NaN  MnPrv        Shed      700      10    2009       WD
# 474          0    NaN    NaN         NaN        0       7    2007      New
# 187          0    NaN  GdPrv         NaN        0       6    2009       WD
# 1257         0    NaN    NaN         NaN        0       8    2008       WD
#
#      SaleCondition  SalePrice
# Id
# 414         Normal     115000
# 6           Normal     143000
# 474        Partial     440000
# 187         Normal     173000
# 1257        Normal     301500

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Continuous data

# %%
df_continuous = df_master.select_dtypes(include='number')
df_continuous.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           2003       196.0         706           0        150          856
# 2           1976         0.0         978           0        284         1262
# 3           2002       162.0         486           0        434          920
# 4           1970         0.0         216           0        540          756
# 5           2000       350.0         655           0        490         1145
#
#     1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1        856       854             0       1710             1             0
# 2       1262         0             0       1262             0             1
# 3        920       866             0       1786             1             0
# 4        961       756             0       1717             1             0
# 5       1145      1053             0       2198             1             0
#
#     FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# Id
# 1          2         1             3             1             8           0
# 2          2         0             3             1             6           1
# 3          2         1             3             1             6           1
# 4          1         0             3             1             7           1
# 5          2         1             4             1             9           1
#
#     GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# Id
# 1        2003.0           2         548           0           61
# 2        1976.0           2         460         298            0
# 3        2001.0           2         608           0           42
# 4        1998.0           3         642           0           35
# 5        2000.0           3         836         192           84
#
#     EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# Id
# 1               0          0            0         0        0       2    2008
# 2               0          0            0         0        0       5    2007
# 3               0          0            0         0        0       9    2008
# 4             272          0            0         0        0       2    2006
# 5               0          0            0         0        0      12    2008
#
#     SalePrice
# Id
# 1      208500
# 2      181500
# 3      223500
# 4      140000
# 5      250000

# %% [markdown]
# - Drop rows with null values

# %%
df_continuous.isna().sum()
# Out:
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
df_continuous = df_continuous.dropna()

# %% [markdown]
# # Model training

# %% [markdown]
# - Split data in train and test sets

# %%
df_final = df_continuous
X, y = df_final.drop(target_column, axis=1), df_final[target_column]
X.shape, y.shape
# Out:
# ((1121, 36), (1121,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape, X_test.shape
# Out:
# ((896, 36), (225, 36))

# %% [markdown]
# - Train a model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model evalution

# %%
import numpy as np
from sklearn.metrics import mean_squared_log_error

def compute_rmsle(y_test: np.ndarray, y_pred: np.ndarray, precision: int = 2) -> float:
    rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))
    return round(rmsle, precision)

# %%
y_pred = model.predict(X_test)
# Replace negative predictions with 0
y_pred = np.where(y_pred < 0, 0, y_pred)
compute_rmsle(y_test, y_pred)
# Out:
# 0.16

# %% [markdown]
# # Inference

# %% [markdown]
# - Read data

# %%
inference_df = pd.read_csv(DATA_DIR / 'test.csv', index_col='Id')
inference_df.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6       1961
# 1462       Norm     1Fam     1Story            6            6       1958
# 1463       Norm     1Fam     2Story            5            5       1997
# 1464       Norm     1Fam     2Story            6            6       1998
# 1465       Norm   TwnhsE     1Story            8            5       1992
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1462          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463          1998     Gable  CompShg     VinylSd     VinylSd       None
# 1464          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
# 1464       926       678             0       1604           0.0           0.0
# 1465      1280         0             0       1280           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0         NaN     Attchd       1961.0
# 1462             6        Typ           0         NaN     Attchd       1958.0
# 1463             6        Typ           1          TA     Attchd       1997.0
# 1464             7        Typ           1          Gd     Attchd       1998.0
# 1465             5        Typ           0         NaN     Attchd       1992.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1461         0    NaN  MnPrv         NaN        0       6    2010       WD
# 1462         0    NaN    NaN        Gar2    12500       6    2010       WD
# 1463         0    NaN  MnPrv         NaN        0       3    2010       WD
# 1464         0    NaN    NaN         NaN        0       6    2010       WD
# 1465         0    NaN    NaN         NaN        0       1    2010       WD
#
#      SaleCondition
# Id
# 1461        Normal
# 1462        Normal
# 1463        Normal
# 1464        Normal
# 1465        Normal

# %% [markdown]
# - Feature engineering

# %%
continuous_inference_df = inference_df.select_dtypes(include='number')
continuous_inference_df.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461          20         80.0    11622            5            6       1961
# 1462          20         81.0    14267            6            6       1958
# 1463          60         74.0    13830            5            5       1997
# 1464          60         78.0     9978            6            6       1998
# 1465         120         43.0     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# Id
# 1461          1961         0.0       468.0       144.0      270.0
# 1462          1958       108.0       923.0         0.0      406.0
# 1463          1998         0.0       791.0         0.0      137.0
# 1464          1998        20.0       602.0         0.0      324.0
# 1465          1992         0.0       263.0         0.0     1017.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# Id
# 1461        882.0       896         0             0        896           0.0
# 1462       1329.0      1329         0             0       1329           0.0
# 1463        928.0       928       701             0       1629           0.0
# 1464        926.0       926       678             0       1604           0.0
# 1465       1280.0      1280         0             0       1280           0.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# Id
# 1461           0.0         1         0             2             1
# 1462           0.0         1         1             3             1
# 1463           0.0         2         1             3             1
# 1464           0.0         2         1             3             1
# 1465           0.0         2         0             2             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# Id
# 1461             5           0       1961.0         1.0       730.0
# 1462             6           0       1958.0         1.0       312.0
# 1463             6           1       1997.0         2.0       482.0
# 1464             7           1       1998.0         2.0       470.0
# 1465             5           0       1992.0         2.0       506.0
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea  MiscVal  MoSold  YrSold
# Id
# 1461         0        0       6    2010
# 1462         0    12500       6    2010
# 1463         0        0       3    2010
# 1464         0        0       6    2010
# 1465         0        0       1    2010

# %%
continuous_inference_df = continuous_inference_df.dropna()

# %% [markdown]
# - Make inference

# %%
predictions = model.predict(continuous_inference_df)
predictions
# Out:
# array([111666.33623996, 129636.01609564, 171151.13778385, ...,
#         60341.8279192 , 166847.07509726, 257872.73331479])

# %%
# Check if there is negative predictions, if so get their indexs
np.where(predictions < 0)
# Out:
# (array([1109]),)

# %%
predictions[1109]
# Out:
# -2940.47158886143

# %%
# Replace negative predictions with 0
predictions = np.where(predictions < 0, 0, predictions)
np.where(predictions < 0)
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# # Submission
# - [Kaggle AAPI usage](https://www.kaggle.com/docs/api)

# %% [markdown]
# - Prepare submission file

# %%
continuous_inference_df.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461          20         80.0    11622            5            6       1961
# 1462          20         81.0    14267            6            6       1958
# 1463          60         74.0    13830            5            5       1997
# 1464          60         78.0     9978            6            6       1998
# 1465         120         43.0     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# Id
# 1461          1961         0.0       468.0       144.0      270.0
# 1462          1958       108.0       923.0         0.0      406.0
# 1463          1998         0.0       791.0         0.0      137.0
# 1464          1998        20.0       602.0         0.0      324.0
# 1465          1992         0.0       263.0         0.0     1017.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# Id
# 1461        882.0       896         0             0        896           0.0
# 1462       1329.0      1329         0             0       1329           0.0
# 1463        928.0       928       701             0       1629           0.0
# 1464        926.0       926       678             0       1604           0.0
# 1465       1280.0      1280         0             0       1280           0.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# Id
# 1461           0.0         1         0             2             1
# 1462           0.0         1         1             3             1
# 1463           0.0         2         1             3             1
# 1464           0.0         2         1             3             1
# 1465           0.0         2         0             2             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# Id
# 1461             5           0       1961.0         1.0       730.0
# 1462             6           0       1958.0         1.0       312.0
# 1463             6           1       1997.0         2.0       482.0
# 1464             7           1       1998.0         2.0       470.0
# 1465             5           0       1992.0         2.0       506.0
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea  MiscVal  MoSold  YrSold
# Id
# 1461         0        0       6    2010
# 1462         0    12500       6    2010
# 1463         0        0       3    2010
# 1464         0        0       6    2010
# 1465         0        0       1    2010

# %%
continuous_inference_df[target_column] = predictions
continuous_inference_df.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461          20         80.0    11622            5            6       1961
# 1462          20         81.0    14267            6            6       1958
# 1463          60         74.0    13830            5            5       1997
# 1464          60         78.0     9978            6            6       1998
# 1465         120         43.0     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# Id
# 1461          1961         0.0       468.0       144.0      270.0
# 1462          1958       108.0       923.0         0.0      406.0
# 1463          1998         0.0       791.0         0.0      137.0
# 1464          1998        20.0       602.0         0.0      324.0
# 1465          1992         0.0       263.0         0.0     1017.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# Id
# 1461        882.0       896         0             0        896           0.0
# 1462       1329.0      1329         0             0       1329           0.0
# 1463        928.0       928       701             0       1629           0.0
# 1464        926.0       926       678             0       1604           0.0
# 1465       1280.0      1280         0             0       1280           0.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# Id
# 1461           0.0         1         0             2             1
# 1462           0.0         1         1             3             1
# 1463           0.0         2         1             3             1
# 1464           0.0         2         1             3             1
# 1465           0.0         2         0             2             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# Id
# 1461             5           0       1961.0         1.0       730.0
# 1462             6           0       1958.0         1.0       312.0
# 1463             6           1       1997.0         2.0       482.0
# 1464             7           1       1998.0         2.0       470.0
# 1465             5           0       1992.0         2.0       506.0
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea  MiscVal  MoSold  YrSold      SalePrice
# Id
# 1461         0        0       6    2010  111666.336240
# 1462         0    12500       6    2010  129636.016096
# 1463         0        0       3    2010  171151.137784
# 1464         0        0       6    2010  198610.157456
# 1465         0        0       1    2010  197004.776613

# %% [markdown]
# - To do the submission, we need to have a prediction for all the samples. However, because we dropped the samples with missing continuous values, we don't have them in `continuous_inference_df`. Therefore, we need to get their ids from the original dataframe `inference_df` and set their predictions to 0.

# %%
continuous_inference_df = continuous_inference_df[[target_column]].reset_index()
continuous_inference_df.head()
# Out:
#      Id      SalePrice
# 0  1461  111666.336240
# 1  1462  129636.016096
# 2  1463  171151.137784
# 3  1464  198610.157456
# 4  1465  197004.776613

# %%
inference_ids_df = inference_df.reset_index()[['Id']]
inference_ids_df.head()
# Out:
#      Id
# 0  1461
# 1  1462
# 2  1463
# 3  1464
# 4  1465

# %%
f'Number of missing predictions = {len(inference_ids_df) - len(continuous_inference_df)}'
# Out:
# 'Number of missing predictions = 313'

# %%
submission_df = inference_ids_df.merge(continuous_inference_df, on='Id', how='left')
submission_df.head()
# Out:
#      Id      SalePrice
# 0  1461  111666.336240
# 1  1462  129636.016096
# 2  1463  171151.137784
# 3  1464  198610.157456
# 4  1465  197004.776613

# %% [markdown]
# - Fill missing predictions (records we dropped because they had missing values in continuous columns)

# %%
# Validate the number of missing predictions
submission_df[target_column].isna().sum() == len(inference_ids_df) - len(continuous_inference_df)
# Out:
# True

# %%
# Fill missing values with 0
submission_df[target_column] = submission_df[target_column].fillna(0)
submission_df[target_column].isna().sum()
# Out:
# 0

# %%
 # Save submission file
submission_file_path = DATA_DIR / 'submission.csv'
submission_df.to_csv(submission_file_path, index=False)

# %%
pd.read_csv(DATA_DIR / 'submission.csv')
# Out:
#         Id      SalePrice
# 0     1461  111666.336240
# 1     1462  129636.016096
# 2     1463  171151.137784
# 3     1464  198610.157456
# 4     1465  197004.776613
# ...    ...            ...
# 1454  2915       0.000000
# 1455  2916   60341.827919
# 1456  2917  166847.075097
# 1457  2918       0.000000
# 1458  2919  257872.733315
#
# [1459 rows x 2 columns]

# %% [markdown]
# - Make submission

# %%
# Used to prevent making a submission in case of `notebook run-all`
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-31-77407f103379> in <module>
#       1 # Used to prevent making a submission in case of `notebook run-all`
# ----> 2 assert False
#
# AssertionError:

# %%
# !kaggle competitions submit -c house-prices-advanced-regression-techniques -f ../../data/house-prices/submission.csv -m dummy-model

# %%
# !kaggle competitions submissions -c house-prices-advanced-regression-techniques

# %% [markdown]
# # Continuous data & categorical data

# %%
import pandas as pd
df_master = pd.read_csv("F:\Lectures/2ed\Data science in production\house-prices/train.csv", index_col='Id')
df_master.sample(5)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 390           60       RL         96.0    12474   Pave   NaN      Reg
# 1128          20       RL        182.0    14572   Pave   NaN      IR3
# 210           20       RL         75.0     8250   Pave   NaN      Reg
# 762           30       RM         60.0     6911   Pave   NaN      Reg
# 982           60       RL         98.0    12203   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 390          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1128         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 210          Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 762          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 982          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 390        0      8    2008       New        Partial     426000
# 1128       0     11    2007        WD         Family     259000
# 210        0      7    2008        WD         Normal     145000
# 762        0     10    2009        WD         Normal     100000
# 982        0      7    2009        WD         Normal     336000
#
# [5 rows x 80 columns]

# %%
df_master.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 80, dtype: object

# %%
df_cate = df_master.select_dtypes(include='object')
df_cate.head()
# Out:
#    MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2        RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 3        RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 4        RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 5        RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#    Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# Id                          ...
# 1       CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 2       Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 3       CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 4       Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 5       NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
#    PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# Id
# 1           Y    NaN   NaN         NaN       WD        Normal
# 2           Y    NaN   NaN         NaN       WD        Normal
# 3           Y    NaN   NaN         NaN       WD        Normal
# 4           Y    NaN   NaN         NaN       WD       Abnorml
# 5           Y    NaN   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
list = ['MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType',
        'HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond',
        'BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu',
        'GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']
df_total = df_master
for i in range(43):
    column = list[i]
    df_total = pd.get_dummies(df_total, columns=[column], prefix=[column])
    
df_total.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# Id                                                    ...
# 1           2003       196.0         706           0  ...               0
# 2           1976         0.0         978           0  ...               0
# 3           2002       162.0         486           0  ...               0
# 4           1970         0.0         216           0  ...               0
# 5           2000       350.0         655           0  ...               0
#
#     SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# Id
# 1              0             0            1                      0
# 2              0             0            1                      0
# 3              0             0            1                      0
# 4              0             0            1                      1
# 5              0             0            1                      0
#
#     SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# Id
# 1                       0                     0                     0
# 2                       0                     0                     0
# 3                       0                     0                     0
# 4                       0                     0                     0
# 5                       0                     0                     0
#
#     SaleCondition_Normal  SaleCondition_Partial
# Id
# 1                      1                      0
# 2                      1                      0
# 3                      1                      0
# 4                      0                      0
# 5                      1                      0
#
# [5 rows x 289 columns]

# %%
df_total.isna().sum()
# Out:
# MSSubClass                 0
# LotFrontage              259
# LotArea                    0
# OverallQual                0
# OverallCond                0
#                         ...
# SaleCondition_AdjLand      0
# SaleCondition_Alloca       0
# SaleCondition_Family       0
# SaleCondition_Normal       0
# SaleCondition_Partial      0
# Length: 289, dtype: int64

# %%
#df_total = df_total.dropna()
#df_total.dtypes
#df_total.fillna(df_total.mean())
avg = df_total.mean()
avg
# Out:
# MSSubClass                  56.897260
# LotFrontage                 70.049958
# LotArea                  10516.828082
# OverallQual                  6.099315
# OverallCond                  5.575342
#                              ...
# SaleCondition_AdjLand        0.002740
# SaleCondition_Alloca         0.008219
# SaleCondition_Family         0.013699
# SaleCondition_Normal         0.820548
# SaleCondition_Partial        0.085616
# Length: 289, dtype: float64

# %%
df_total = df_total.fillna(avg)

# %%
df_total.isna().sum()
# Out:
# MSSubClass               0
# LotFrontage              0
# LotArea                  0
# OverallQual              0
# OverallCond              0
#                         ..
# SaleCondition_AdjLand    0
# SaleCondition_Alloca     0
# SaleCondition_Family     0
# SaleCondition_Normal     0
# SaleCondition_Partial    0
# Length: 289, dtype: int64

# %% [markdown]
# # Model training
# * Split data in train and test sets

# %%
X, y = df_total.drop('SalePrice', axis=1), df_total['SalePrice']
X.shape, y.shape
# Out:
# ((1460, 288), (1460,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape, X_test.shape
# Out:
# ((1168, 288), (292, 288))

# %%
correlation = df_total.corr()
correlation
# Out:
#                        MSSubClass  LotFrontage   LotArea  OverallQual  \
# MSSubClass               1.000000    -0.357056 -0.139781     0.032628
# LotFrontage             -0.357056     1.000000  0.306795     0.234196
# LotArea                 -0.139781     0.306795  1.000000     0.105806
# OverallQual              0.032628     0.234196  0.105806     1.000000
# OverallCond             -0.059316    -0.052820 -0.005636    -0.091932
# ...                           ...          ...       ...          ...
# SaleCondition_AdjLand    0.016241    -0.037020 -0.013208    -0.041677
# SaleCondition_Alloca     0.030002    -0.018090  0.008966    -0.044950
# SaleCondition_Family     0.000983     0.015818 -0.010781    -0.025515
# SaleCondition_Normal     0.024359    -0.072074  0.005711    -0.143282
# SaleCondition_Partial   -0.051068     0.124842  0.022635     0.323295
#
#                        OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# MSSubClass               -0.059316   0.027850      0.040581    0.022895
# LotFrontage              -0.052820   0.117598      0.082746    0.179283
# LotArea                  -0.005636   0.014228      0.013788    0.103960
# OverallQual              -0.091932   0.572323      0.550684    0.410238
# OverallCond               1.000000  -0.375983      0.073741   -0.127788
# ...                            ...        ...           ...         ...
# SaleCondition_AdjLand    -0.038888  -0.045601     -0.040294   -0.011959
# SaleCondition_Alloca     -0.033444  -0.010104     -0.020727   -0.009689
# SaleCondition_Family     -0.023873  -0.035785     -0.048056   -0.009914
# SaleCondition_Normal      0.161642  -0.158427     -0.120577   -0.084241
# SaleCondition_Partial    -0.151659   0.343895      0.322837    0.165606
#
#                        BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# MSSubClass              -0.069836   -0.065649  ...        0.014005
# LotFrontage              0.215828    0.043340  ...       -0.051787
# LotArea                  0.214103    0.111170  ...       -0.015040
# OverallQual              0.239666   -0.059119  ...       -0.021172
# OverallCond             -0.046231    0.040229  ...       -0.019779
# ...                           ...         ...  ...             ...
# SaleCondition_AdjLand   -0.014874   -0.015130  ...       -0.003073
# SaleCondition_Alloca     0.021369   -0.026277  ...       -0.005337
# SaleCondition_Family     0.000765   -0.007929  ...       -0.006909
# SaleCondition_Normal    -0.019560    0.041207  ...        0.027414
# SaleCondition_Partial    0.044912   -0.085761  ...       -0.017938
#
#                        SaleType_New  SaleType_Oth  SaleType_WD  \
# MSSubClass                -0.045156     -0.014555     0.026359
# LotFrontage                0.126580     -0.023461    -0.089928
# LotArea                    0.020039     -0.005722    -0.002292
# OverallQual                0.327412     -0.057962    -0.225013
# OverallCond               -0.156175     -0.050663     0.163684
# ...                             ...           ...          ...
# SaleCondition_AdjLand     -0.015827     -0.002378     0.020457
# SaleCondition_Alloca      -0.027489     -0.004131     0.035530
# SaleCondition_Family      -0.035587     -0.005348     0.028599
# SaleCondition_Normal      -0.645698     -0.097031     0.634322
# SaleCondition_Partial      0.986819     -0.013885    -0.769559
#
#                        SaleCondition_Abnorml  SaleCondition_AdjLand  \
# MSSubClass                          0.005003               0.016241
# LotFrontage                        -0.021846              -0.037020
# LotArea                            -0.029126              -0.013208
# OverallQual                        -0.103535              -0.041677
# OverallCond                        -0.046367              -0.038888
# ...                                      ...                    ...
# SaleCondition_AdjLand              -0.014289               1.000000
# SaleCondition_Alloca               -0.024817              -0.004772
# SaleCondition_Family               -0.032128              -0.006177
# SaleCondition_Normal               -0.582947              -0.112080
# SaleCondition_Partial              -0.083419              -0.016038
#
#                        SaleCondition_Alloca  SaleCondition_Family  \
# MSSubClass                         0.030002              0.000983
# LotFrontage                       -0.018090              0.015818
# LotArea                            0.008966             -0.010781
# OverallQual                       -0.044950             -0.025515
# OverallCond                       -0.033444             -0.023873
# ...                                     ...                   ...
# SaleCondition_AdjLand             -0.004772             -0.006177
# SaleCondition_Alloca               1.000000             -0.010729
# SaleCondition_Family              -0.010729              1.000000
# SaleCondition_Normal              -0.194663             -0.252006
# SaleCondition_Partial             -0.027856             -0.036062
#
#                        SaleCondition_Normal  SaleCondition_Partial
# MSSubClass                         0.024359              -0.051068
# LotFrontage                       -0.072074               0.124842
# LotArea                            0.005711               0.022635
# OverallQual                       -0.143282               0.323295
# OverallCond                        0.161642              -0.151659
# ...                                     ...                    ...
# SaleCondition_AdjLand             -0.112080              -0.016038
# SaleCondition_Alloca              -0.194663              -0.027856
# SaleCondition_Family              -0.252006              -0.036062
# SaleCondition_Normal               1.000000              -0.654323
# SaleCondition_Partial             -0.654323               1.000000
#
# [289 rows x 289 columns]

# %% [markdown]
# * Train a model

# %%
#from sklearn.linear_model import LinearRegression
#model = LinearRegression()
#model.fit(X_train, y_train)

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Model evalution

# %%
import numpy as np
from sklearn.metrics import mean_squared_log_error

def compute_rmsle(y_test: np.ndarray, y_pred: np.ndarray, precision: int = 2) -> float:
    rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))
    return round(rmsle, precision)

# %%
y_pred = model.predict(X_test)
# Replace negative predictions with 0
y_pred = np.where(y_pred < 0, 0, y_pred)
compute_rmsle(y_test, y_pred)
#y_pred
# Out:
# 0.3

# %% [markdown]
# # Inference
# * Read data

# %%
inference_df = pd.read_csv("F:\Lectures/2ed\Data science in production\house-prices/test.csv", index_col='Id')
inference_df.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461         NaN       0       6    2010        WD         Normal
# 1462        Gar2   12500       6    2010        WD         Normal
# 1463         NaN       0       3    2010        WD         Normal
# 1464         NaN       0       6    2010        WD         Normal
# 1465         NaN       0       1    2010        WD         Normal
#
# [5 rows x 79 columns]

# %%
inference_df.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 79, dtype: object

# %%
list = ['MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType',
        'HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond',
        'BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu',
        'GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']
infe_total = inference_df
for i in range(43):
    column = list[i]
    infe_total = pd.get_dummies(infe_total, columns=[column], prefix=[column])
    
infe_total.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461          20         80.0    11622            5            6       1961
# 1462          20         81.0    14267            6            6       1958
# 1463          60         74.0    13830            5            5       1997
# 1464          60         78.0     9978            6            6       1998
# 1465         120         43.0     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# Id                                                      ...
# 1461          1961         0.0       468.0       144.0  ...               0
# 1462          1958       108.0       923.0         0.0  ...               0
# 1463          1998         0.0       791.0         0.0  ...               0
# 1464          1998        20.0       602.0         0.0  ...               0
# 1465          1992         0.0       263.0         0.0  ...               0
#
#       SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# Id
# 1461             0             0            1                      0
# 1462             0             0            1                      0
# 1463             0             0            1                      0
# 1464             0             0            1                      0
# 1465             0             0            1                      0
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# Id
# 1461                      0                     0                     0
# 1462                      0                     0                     0
# 1463                      0                     0                     0
# 1464                      0                     0                     0
# 1465                      0                     0                     0
#
#       SaleCondition_Normal  SaleCondition_Partial
# Id
# 1461                     1                      0
# 1462                     1                      0
# 1463                     1                      0
# 1464                     1                      0
# 1465                     1                      0
#
# [5 rows x 270 columns]

# %%
list2 = ['Electrical_Mix','Heating_Floor','Heating_GasA','Exterior2nd_Other','Exterior1st_Stone','Exterior1st_ImStucc','RoofMatl_Membran',
         'RoofMatl_Metal','RoofMatl_Roll','RoofMatl_ClyTile','HouseStyle_2.5Fin','Condition2_RRAe','Condition2_RRAn','Condition2_RRNn',
         'Utilities_NoSeWa','Heating_OthW','GarageQual_Ex','PoolQC_Fa','MiscFeature_TenC']

for i in range(19):
    new_column = list2[i]
    infe_total[new_column] = 0
    
infe_total.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461          20         80.0    11622            5            6       1961
# 1462          20         81.0    14267            6            6       1958
# 1463          60         74.0    13830            5            5       1997
# 1464          60         78.0     9978            6            6       1998
# 1465         120         43.0     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  RoofMatl_ClyTile  \
# Id                                                      ...
# 1461          1961         0.0       468.0       144.0  ...                 0
# 1462          1958       108.0       923.0         0.0  ...                 0
# 1463          1998         0.0       791.0         0.0  ...                 0
# 1464          1998        20.0       602.0         0.0  ...                 0
# 1465          1992         0.0       263.0         0.0  ...                 0
#
#       HouseStyle_2.5Fin  Condition2_RRAe  Condition2_RRAn  Condition2_RRNn  \
# Id
# 1461                  0                0                0                0
# 1462                  0                0                0                0
# 1463                  0                0                0                0
# 1464                  0                0                0                0
# 1465                  0                0                0                0
#
#       Utilities_NoSeWa  Heating_OthW  GarageQual_Ex  PoolQC_Fa  \
# Id
# 1461                 0             0              0          0
# 1462                 0             0              0          0
# 1463                 0             0              0          0
# 1464                 0             0              0          0
# 1465                 0             0              0          0
#
#       MiscFeature_TenC
# Id
# 1461                 0
# 1462                 0
# 1463                 0
# 1464                 0
# 1465                 0
#
# [5 rows x 288 columns]

# %%
infe_total.dtypes
# Out:
# MSSubClass            int64
# LotFrontage         float64
# LotArea               int64
# OverallQual           int64
# OverallCond           int64
#                      ...
# Utilities_NoSeWa      int64
# Heating_OthW          int64
# GarageQual_Ex         int64
# PoolQC_Fa             int64
# MiscFeature_TenC      int64
# Length: 288, dtype: object

# %%
infe_total = infe_total.fillna(infe_total.mean())
infe_total.isna().sum()
# Out:
# MSSubClass          0
# LotFrontage         0
# LotArea             0
# OverallQual         0
# OverallCond         0
#                    ..
# Utilities_NoSeWa    0
# Heating_OthW        0
# GarageQual_Ex       0
# PoolQC_Fa           0
# MiscFeature_TenC    0
# Length: 288, dtype: int64

# %% [markdown]
# * Make inference

# %%
predictions = model.predict(infe_total)
predictions
# Out:
# array([145000, 190000, 175000, ..., 160000, 135000, 155000], dtype=int64)

# %%
np.where(predictions < 0)
# Out:
# (array([], dtype=int64),)
